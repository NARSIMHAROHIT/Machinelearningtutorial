# %% [markdown]
# #ML FLOW TRACKING SERVER

# %%
import mlflow

# %%
#set the tracking url to the local sserver
mlflow.set_tracking_uri("http://127.0.0.1:5001")

# %%
mlflow.set_experiment("Check local host connection")
with mlflow.start_run():
    mlflow.log_param("param1", 5)
    mlflow.log_metric("metric1", 0.85)
# Out:
# 🏃 View run angry-ray-441 at: http://127.0.0.1:5001/#/experiments/1/runs/b58cb61ccbc44c0dbdf28f0cd829492c
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1
